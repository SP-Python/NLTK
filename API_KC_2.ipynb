# %%
from mws import mws
import urllib
import urllib.request
import urllib.error
import json
from pandas.io.json import json_normalize
import argparse
import parser
import xml.etree.ElementTree as ET
import xmltodict
from datetime import datetime
import requests
import os
import pandas as pd
import numpy as np
import pandas as pd
from pandas import DataFrame
import pandas as pd
import re
import lxml
from lxml import html
import time
from time import sleep
from dateutil import parser as dateparser
import json
import csv
from random import choice
import js2xml
import scrapy
import datetime
from datetime import date
from datetime import time
import sys
import random
from lxml.html import fromstring

from pandas.io import sql
import mysql.connector
import sqlalchemy
from sqlalchemy import create_engine

#engine=mysql.connector.connect(user='myadmin@globiteserver',password='Admin123$$', host='globiteserver.mysql.database.azure.com',port=3306,
#database='globite_amazon',ssl_ca='C:\ssl\BaltimoreCyberTrustRoot.crt.pem')
#engine = create_engine('mysql+mysqlconnector://myadmin@globiteserver:Admin123$$@globiteserver.mysql.database.azure.com:3306/globite_amazon', connect_args = {'ssl_ca':'C:\ssl\BaltimoreCyberTrustRoot.crt.pem'})
#df.to_sql(name='asin_apidata',con=conn ,if_exists='append',index=False)
engine = create_engine('mysql+mysqlconnector://root:newrootpassword@127.0.0.1:3306/globite_amazon') 
#change to connect your mysql
#if you want to append the data to an existing table

# %%
import smtplib
smtpObj = smtplib.SMTP('smtp-mail.outlook.com', 587)
smtpObj.ehlo()
smtpObj.starttls()
smtpObj.login('consultant2@royale.com.au', 'welcome')
FROM = "consultant2@royale.com.au"
TO = ["consultant2@royale.com.au"] # must be a list

SUBJECT = "API_KC_2 Run"

# %%
def ReadAsin():
    
    AsinList = [        
        
        #'B00R280UQM',
        #'B017XCZY4O',
        #'B005LXPSFI',
        #'B07D25NWLK',
        #'B07D26SSYB',
        
        'B01NCEWK40',
        'B00FTUMG94',
        'B00HHBR026',
        'B078VZXNYX',
        'B00HHBR008',
        
        #'B01IB8QBQY',
        #'B00R280UQM',
        #'B00HHBR008',
        #'B017XL0148',
        #'B017XCZY4O',
        #'B074SVNDKL', 
        
        #'B01MU18ORU',
        #'B06ZXYL6GV',
        #'B01E923UCY',
        #'B01B2JUS4K',
        #'B078LJ4VNN',
        #'B076V6NH3V',
        
        #'B014VBIEZQ',
        #'B00FTUMGLW',
        #'B079YXLYM9',
        #'B07BNNV4GT',
        #'B005LXPSGM',
        #'B0711J3VCL',
        
        #'B073Q5XPCM',
        #'B07CTGB9ND',
        #'B07664WLQ3',
        #'B079YYLSMT',
        #'B074CWCT8J',
        #'B016ICV6OM',
        
        #'B074KQ4C85',
        #'B06ZZ372KV',
        #'B014VBI16S',
        #'B0773NVNV8',
        #'B00OY893YI',
        #'B014VBI5MS',
        
        ### Neck Pillow ###
        
        #'B01DODMU9I',
        #'B00LB7REFK',
        #'B06WWFYCSG',
        #'B077SLWK5C',
        #'B00JIPG09S',
        
        ## Luggage Tags
        
        #'B01CKN7HBO',
        #'B00QMGOXXG',
        #'B074Z4F6WN',
        #'B071PDTV7Q',
        #'B07124RTTR',
        #'B071PDTV7Q',
        
        # Travel Lock
        
        #'B07CF87JZM',
        #'B073NYBSD3',
        #'B000WO84Z2',
        #'B01NAOEBZ0',
        #'B01N7ILPEL',
        #'B00Q0PACEI',
        #'B015TA6GP8',
        #'B0131LLVGG',
    ]
    
    for AsinId in AsinList:
        url = "https://www.amazon.com/dp/"+ AsinId
        print ("Processing: "+url)
        #sleep(15)
        #extracted_data.append(AmzonParser(AsinId))
        extracted_data = []
        extracted_data.append(AmzonScrapeParser(url))
        print(extracted_data)
        df = pd.DataFrame(extracted_data)
        cols = [
        #,
        'asin_id_api', 
        'brand_api',
        'title_api',
        'small_image_api',
        'sale_price_api',
        'best_sellers_rank_api',
        'date_exported',
        'curr_date',
        'search_keyword', 
        'asin_id',
        'title',
        'sale_price',
        'category',
        'original_price',
        'availability',
        'brand',
        'feature_bullets',
        'descritpion',
        'customer_reviews', 
        'search_url',
        'asin_url',
        'Five_Star_Rating',
        'Four_Star_Rating',
        'Three_Star_Rating',
        'Two_Star_Rating',
        'One_Star_Rating',
        'amazon_best_sellers_rank_1',
        'amazon_best_sellers_category_1',
        'amazon_best_sellers_rank_2',
        'amazon_best_sellers_category_2',
        'amazon_best_sellers_rank_3',
        'amazon_best_sellers_category_3',
        'fullfilled_by_amazon',
        'amazons_choice',
        'amazons_leftside_image',
        'count_leftside_images',
        'amazons_bottom_image',
        'count_colour_variations',
        ]
 
        df = df[cols]
    
#-----------------------------------------------------------------------------------------------------------------------
# Transfering the Data to MySQL Database.
        df.to_sql(con=engine, name='amazon_products', if_exists='append',index=True)

#df.to_sql(con=engine, name='amazon_search', if_exists='append',index=False)

        sleep(20)

# %%
#userInput = input('Enter a search term: ')
#print(userInput)

userInput = 'Key Competitors'

#-----------------------------------------------------------------------------------------------------------------------

# URL for searching for products on amazon

AMAZON = "https://www.amazon.com"
BaseSearchUrl = "https://www.amazon.com/s/?keywords="
AMAZON_URL = BaseSearchUrl + userInput.replace(' ', '+')
AMAZON_DP = "https://www.amazon.com/dp/"

#-----------------------------------------------------------------------------------
Amazon_Page = "https://www.amazon.com/s/ref=sr_pg_"
SeachKeyword = "?keywords="
#-----------------------------------------------------------------------------------
Amazon_Page2 = "https://www.amazon.com/s/?"
SeachKeyword2 = "keywords="

#-----------------------------------------------------------------------------------
PageSearchUrl = "https://www.amazon.com/s/ref=sr_pg_1?keywords="
PAGE_AMAZON_URL = PageSearchUrl + userInput.replace(' ', '+')
#-----------------------------------------------------------------------------------

url = AMAZON_URL
#print(AMAZON_URL)
#print(AMAZON_DP)
#print(PAGE_AMAZON_URL)


def AmzonScrapeParser(url):
#-----------------------------------------------------------------------------------------------------------------------
# Method to return a random user Agent from the list, so that it doesn't get caught in Amazon as a Bot.
# list of available user agents
#-----------------------------------------------------------------------------------------------------------------------

	desktop_agents =['Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/600.8.9 (KHTML, like Gecko) Version/8.0.8 Safari/600.8.9',
			'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36',
			'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/534.27 (KHTML, like Gecko) Chrome/12.0.712.0 Safari/534.27',
			'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/13.0.782.24 Safari/535.1',
			'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.2 (KHTML, like Gecko) Chrome/15.0.874.120 Safari/535.2',
			'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.7 (KHTML, like Gecko) Chrome/16.0.912.36 Safari/535.7',
			'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.90 Safari/537.36',     
			'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
			'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
			'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
			'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/602.2.14 (KHTML, like Gecko) Version/10.0.1 Safari/602.2.14',
			'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
			'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
			'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
			'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
			'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
			'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0',
#Chrome
			'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
			'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
			'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
			'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
			'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
			'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
			'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
			'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
			'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
			'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
#Firefox
			'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
			'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
			'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
			'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
			'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0) like Gecko',
			'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
			'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
			'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
			'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
			'Mozilla/5.0 (Windows NT 6.1; Win64; x64; Trident/7.0; rv:11.0) like Gecko',
			'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
			'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)',
			'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)'
]

	def random_headers():
		return {'User-Agent': choice(desktop_agents),'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'}

	HEADERS = []
	HEADERS = random_headers()
    
	def get_proxies():
		proxyurl = 'https://free-proxy-list.net/'
		response = requests.get(proxyurl,headers=HEADERS)
		parser = fromstring(response.text)
		#print(parser)
		proxies = []
		for i in parser.xpath('//tbody/tr')[ :50]:
			if i.xpath('.//td[7][contains(text(),"yes")]'):
            #Grabbing IP and corresponding PORT
				proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
				proxies.append(proxy)
		return proxies

	proxies_list = get_proxies()
	print(proxies_list)
    
	#proxies = {'https': choice(proxies_list)}
	#print(proxies)
    
	try:
		proxies = {'https': choice(proxies_list)}
		print(proxies)
		page = requests.get(url,headers=HEADERS, proxies=proxies)
		print("Connected to the Proxy IP")
	except:
        #Most free proxies will often get connection errors. You will have retry the entire request using another proxy to work. 
        #We will just skip retries as its beyond the scope of this tutorial and we are only downloading a single url
		proxies2 = {'https': choice(proxies_list)}
		page = requests.get(url,headers=HEADERS, proxies=proxies2) 
		print("Skipping. Connection Error to the Proxy IP")

#-----------------------------------------------------------------------------------------------------------------------
    
	while True:
		sleep(50)
		try:
			doc = html.fromstring(page.content)
			search_key = 'Key Competitors' #'Key Competitors'#'Competitor Packing Cubes'
			#Date_Time = datetime.datetime.now()
			#d = datetime.datetime.now()
			#currentdate = d.date()
			asin_id = url.split("https://www.amazon.com/dp/")[1] if url else None
            
			Date_Time = datetime.datetime.now()
			d = datetime.datetime.now()
			currentdate = Date_Time.date()
            
			#print(asin_id)
            
			main_url = AMAZON_URL
            
			XPATH_NAME = '//h1[contains(@id,"title") or contains(@id,"productTitle")]//text()'
            
			XPATH_SALE_PRICE = 'substring-after(normalize-space(//span[(@id = "priceblock_ourprice")]/text()), "$")'
            
			XPATH_ORIGINAL_PRICE = '//td[contains(text(),"List Price") or contains(text(),"M.R.P") or contains(text(),"Price")]/following-sibling::td/text()'
            
			XPATH_CATEGORY = '//a[@class="a-link-normal a-color-tertiary"]//text()'
            
			XPATH_AVAILABILITY = '//div[@id="availability"]//text()'
            
			XPATH_BRAND = '//a[@id="bylineInfo"]//text()'
            
			XPATH_FEATURE_BULLETS = '//div[@id="feature-bullets"]//text()'
            
			XPATH_PRODUCT_DESC = '//div[@class="a-section launchpad-text-left-justify" or @id="productDescription" or @id ="detailBulletsWrapper_feature_div"]//text()'
            
			XPATH_CUSTOMER_REVIEWS = '//span[(@id = "acrCustomerReviewText")]/text()'
            
			XPATH_AGGREGATE_RATING = '//table[@id="histogramTable"]//tr'
            
			XPATH_Total_Rating = '//table[@id="histogramTable"]//tr[@class = "a-histogram-row"]//td[@class="a-text-right aok-nowrap"]//text()'

			#XPATH_BEST_SELLERS_RANK1= '//div//li[@id="SalesRank"]//text()'
			#XPATH_BEST_SELLERS_RANK2= '//table[@id = "productDetails_detailBullets_sections1"]//tr//td//span//text()'
            
			XPATH_FULLFILLED_BY_AMAZON = '//div[@id="merchant-info"]//a[@id="SSOFpopoverLink"]//text()'
            
			XPATH_AMAZONS_CHOICE = '//div//span//span[@class="a-size-small aok-float-left ac-badge-rectangle"]//span//text()'
            
			XPATH_image = '//div[@id = "altImages"]//img/@src'
			XPATH_Vertical_image = '//ul[@class="a-unordered-list a-nostyle a-button-list a-vertical a-spacing-top-extra-large"]//li[contains(@class,"a-spacing-small item imageThumbnail a-declarative")]//img/@src'

			XPATH_Bottom_image = '//div[@id = "twister_feature_div"]//img/@src'
			XPATH_Bottom_image2 = '//ul[@class = "a-unordered-list a-nostyle a-button-list a-declarative a-button-toggle-group a-horizontal a-spacing-top-micro swatches swatchesSquare imageSwatches"]//img/@src'
            
                    
			total_ratings  = doc.xpath(XPATH_AGGREGATE_RATING)
			ratings_dict = {}
                        
#grabing the rating  section in product page
			for ratings in total_ratings:
				extracted_rating = ratings.xpath('./td//a//text()')
				if extracted_rating:
					rating_key = extracted_rating[0]
					raw_raing_value = extracted_rating[1]
					rating_value = raw_raing_value
					if rating_key:
						ratings_dict.update({rating_key:rating_value})
          
			#IMAGE_JS = []
			RAW_NAME = doc.xpath(XPATH_NAME)
            
			RAW_SALE_PRICE = doc.xpath(XPATH_SALE_PRICE)
            
			RAW_CATEGORY = doc.xpath(XPATH_CATEGORY)
            
			RAW_ORIGINAL_PRICE = doc.xpath(XPATH_ORIGINAL_PRICE)
            
			RAw_AVAILABILITY = doc.xpath(XPATH_AVAILABILITY)
            
			RAW_BRAND = doc.xpath(XPATH_BRAND)
            
			RAW_FEATURE_BULLETS = doc.xpath(XPATH_FEATURE_BULLETS)
            
			RAW_PROD_DESC = doc.xpath(XPATH_PRODUCT_DESC)
            
			RAW_CUSTOMER_REVIEWS = doc.xpath(XPATH_CUSTOMER_REVIEWS)
            
			RAW_Total_Rating = doc.xpath(XPATH_Total_Rating)
            
			RAW_FULLFILLED_BY_AMAZON = doc.xpath(XPATH_FULLFILLED_BY_AMAZON)
            
			RAW_AMAZONS_CHOICE = doc.xpath(XPATH_AMAZONS_CHOICE)
            
			#RAW_image_js = []
			RAW_VERTICAL_IMAGE1 = doc.xpath(XPATH_image) or doc.xpath(XPATH_Vertical_image)
			#print(RAW_VERTICAL_IMAGE1)
            
			#RAW_VERTICAL_IMAGE2 = doc.xpath(XPATH_Vertical_image) if XPATH_Vertical_image else 0
			#print(RAW_VERTICAL_IMAGE2)            
            
			vimg1 = 0
			Vertical_image1 = []
			if RAW_VERTICAL_IMAGE1 :
				while vimg1 < len(list(RAW_VERTICAL_IMAGE1)):
					Vertical_image1.append(RAW_VERTICAL_IMAGE1[vimg1].split("._")[0]+ ".jpg") if RAW_VERTICAL_IMAGE1 else None
					vimg1 = vimg1 + 1
			#print(Vertical_image1)
                    
			#vimg2 = 0
			#Vertical_image2 = []
			#if RAW_VERTICAL_IMAGE2 != None:
				#while vimg2 < len(list(RAW_VERTICAL_IMAGE2)):
					#Vertical_image2.append(RAW_VERTICAL_IMAGE2[vimg2].split("._")[0]+ ".jpg") if RAW_VERTICAL_IMAGE2 else None
					#vimg2 = vimg2 + 1
			#print(Vertical_image2)
            
			RAW_bottom_image1 = doc.xpath(XPATH_Bottom_image) or doc.xpath(XPATH_Bottom_image2)
			#RAW_bottom_image2 = doc.xpath(XPATH_Bottom_image2) if XPATH_Bottom_image2 else 0
			bimg1 = 0
			Bottom_image1 = []
			if RAW_bottom_image1 :
				while bimg1 < len(list(RAW_bottom_image1)):
					Bottom_image1.append(RAW_bottom_image1[bimg1].split("._")[0]+ ".jpg") if RAW_bottom_image1 else None
					bimg1 = bimg1 + 1
                    
			#bimg2 = 0
			#Bottom_image2 = []
			#if RAW_bottom_image2 :
				#while bimg2 < len(list(RAW_bottom_image2)):
					#Bottom_image2.append(RAW_bottom_image2[bimg2].split("._")[0]+ ".jpg") if RAW_bottom_image2 else None
					#bimg2 = bimg2 + 1
                    
			#if RAW_NAME is not None :
			NAME = ' '.join(''.join(RAW_NAME).split()) if RAW_NAME else None
			#NAME = ' '.join(''.join(RAW_NAME).split())
			print(NAME)
			if NAME == None :      
				smtpObj = smtplib.SMTP('smtp-mail.outlook.com', 587)
				smtpObj.ehlo()
				smtpObj.starttls()
				smtpObj.login('consultant2@royale.com.au', 'welcome')
				FROM = "consultant2@royale.com.au"
				TO = ["consultant2@royale.com.au"] # must be a list
				SUBJECT = "API_KC_2 Run"
				
				TEXT = "Hi ERROR, \nThe None Error for API_KC_1 is coming from Amazon \nThanks, Sree"
				message = """From: %s\r\nTo: %s\r\nSubject: %s\r\n\
				# %s
				""" % (FROM, ", ".join(TO), SUBJECT, TEXT)
				smtpObj.sendmail(FROM, TO, message)
				smtpObj.quit()  
				sys.exit("Title is coming as None")

			########Sale Price Correction#######
            
			SALE_PRICE = ''.join(''.join(RAW_SALE_PRICE).split(' - ')[0]).strip() if RAW_SALE_PRICE else None
            
			########Sale Price Correction#######
            
			CATEGORY = ' > '.join([i.strip() for i in RAW_CATEGORY]) if RAW_CATEGORY else None
			ORIGINAL_PRICE = ''.join(RAW_ORIGINAL_PRICE).strip() if RAW_ORIGINAL_PRICE else None
			AVAILABILITY = ''.join(RAw_AVAILABILITY).strip() if RAw_AVAILABILITY else None
			BRAND = ' '.join(''.join(RAW_BRAND).split()).strip() if RAW_BRAND else None
			FEATURE_BULLETS = ' * '.join([i.strip() for i in RAW_FEATURE_BULLETS]) if RAW_FEATURE_BULLETS else None            
			DESCRIPTION = ' * '.join([i.strip() for i in RAW_PROD_DESC]) if RAW_PROD_DESC else None
			CUSTOMER_REVIEWS = (RAW_CUSTOMER_REVIEWS[0].split())[0].replace(',','') if RAW_CUSTOMER_REVIEWS else 0
            
			Total_Rating = ','.join([i.strip() for i in RAW_Total_Rating]) if RAW_Total_Rating else None
            
###--------------------------------------------------------------------------------------------------------------------------

			XPATH_BEST_SELLERS_RANK1= '//div//li[@id="SalesRank"]//text()'
			XPATH_BEST_SELLERS_RANK2= '//table[@id = "productDetails_detailBullets_sections1"]//tr//td//span//text()'
			#bsrpath2 = doc.xpath(XPATH_BEST_SELLERS_RANK2)
			print(doc.xpath(XPATH_BEST_SELLERS_RANK1))
			print(doc.xpath(XPATH_BEST_SELLERS_RANK2))
			#XPATH_BEST_SELLERS_RANK = XPATH_BEST_SELLERS_RANK1 if XPATH_BEST_SELLERS_RANK1 else XPATH_BEST_SELLERS_RANK2
			#if doc.xpath(XPATH_BEST_SELLERS_RANK1) is not None:
			RAW_BEST_SELLERS_RANK = doc.xpath(XPATH_BEST_SELLERS_RANK1) or doc.xpath(XPATH_BEST_SELLERS_RANK2)
				#RAW_BEST_SELLERS_RANK = doc.xpath(XPATH_BEST_SELLERS_RANK1)
			print(RAW_BEST_SELLERS_RANK)
            
			#else:
				#RAW_BEST_SELLERS_RANK = doc.xpath(XPATH_BEST_SELLERS_RANK2)
				#print(RAW_BEST_SELLERS_RANK)
                
			#RAW_BEST_SELLERS_RANK2 = doc.xpath(XPATH_BEST_SELLERS_RANK2)
			#print(RAW_BEST_SELLERS_RANK2)
            
			#if doc.xpath(XPATH_BEST_SELLERS_RANK1) != []:
				#RAW_BEST_SELLERS_RANK1 = doc.xpath(XPATH_BEST_SELLERS_RANK1)
				#BEST_SELLERS_RANK_1 = ' * '.join([i.strip() for i in RAW_BEST_SELLERS_RANK1])
				#print(BEST_SELLERS_RANK_1)
			#else:
				#RAW_BEST_SELLERS_RANK2 = doc.xpath(XPATH_BEST_SELLERS_RANK2)
				#BEST_SELLERS_RANK_2 = ' * '.join([i.strip() for i in RAW_BEST_SELLERS_RANK2])
				#print(BEST_SELLERS_RANK_2)
			#if not RAW_BEST_SELLERS_RANK1:
				#RAW_BEST_SELLERS_RANK = RAW_BEST_SELLERS_RANK2
				#print(RAW_BEST_SELLERS_RANK)
			#else :
				#RAW_BEST_SELLERS_RANK = RAW_BEST_SELLERS_RANK1
				#print(RAW_BEST_SELLERS_RANK)


			#TOTAL_BEST_SELLERS_RANK = BEST_SELLERS_RANK_1 if BEST_SELLERS_RANK_1 else BEST_SELLERS_RANK_2
			TOTAL_BEST_SELLERS_RANK = ' * '.join([i.strip() for i in RAW_BEST_SELLERS_RANK])
			print(TOTAL_BEST_SELLERS_RANK)
			
            
			#TOTAL_BEST_SELLERS_RANK = ' * '.join([i.strip() for i in RAW_BEST_SELLERS_RANK1]) if RAW_BEST_SELLERS_RANK1 else None
			#print(TOTAL_BEST_SELLERS_RANK)
            
			parts = TOTAL_BEST_SELLERS_RANK.split(" #") if TOTAL_BEST_SELLERS_RANK else None
			#print(parts)
			lenparts = len(list(parts))-1 
			#print(lenparts)

			A = 1
			if not A <= lenparts:
				bsr1 = 0
				#print(bsr1)
				cat1 = None
				#print(cat1)
			else:                
				bsr1 = parts[1].split("*")[0].replace(' (','').split(" in ")[0].replace(',','').replace('#','') if parts[1] else 0
               #BEST_SELLERS_RANK1.split(" in ")[0].replace(',','').replace('#','') 
				print(bsr1)
				cat1 = parts[1].split("*")[0].replace(' (','').split(" in ")[1] if parts[1] else None
                #BEST_SELLERS_RANK1.split(" in ")[1].replace(' (','') 
				#print(cat1)

			A = 2
			if not A <= lenparts:
					#bsr2 = 0
				#print(bsr2)
				cat2 = None
				#print(cat2)
			else:
				bsr2 = parts[2].replace(' *  *','').split(" in ")[0].replace(' * > * ',' > ').replace(' * ','').replace('* ','').replace(',','') if parts[2] else 0
                #BEST_SELLERS_RANK2[0].replace(',','').replace(' *  *','') 
				#print(bsr2)
				cat2 = parts[2].replace(' *  *','').split(" in ")[1].replace(' * > * ',' > ').replace(' * ','').replace('* ','') if parts[2] else None
                #BEST_SELLERS_RANK2[1].replace(' * > * ',' > ').replace(' * ','').replace('* ','')
				#print(cat2)
                
### List Index Out of Range Error is coming -- Fixed it..###
			A = 3
			if not A <= lenparts:    
				bsr3 = 0
				#print(bsr3)
				cat3 = None
				#print(cat3)
			else:
				bsr3 = parts[3].split(" in ")[0].replace(',','').replace(' *  *','').replace(',','') if parts[3] else 0
                #BEST_SELLERS_RANK3[0].replace(',','').replace(' *  *','')
				#print(bsr3)
				cat3 = parts[3].split(" in ")[1].replace(' * > * ',' > ').replace(' * ','').replace('* ','') if parts[3] else None
                #BEST_SELLERS_RANK3[1].replace(' * > * ',' > ').replace(' * ','').replace('* ','')
				#print(cat3)

###--------------------------------------------------------------------------------------------------------------------------

			FULLFILLED_BY_AMAZON1 = ' > '.join([i.strip() for i in RAW_FULLFILLED_BY_AMAZON]) if RAW_FULLFILLED_BY_AMAZON else None

			AMAZONS_CHOICE1 = ' '.join([i.strip() for i in RAW_AMAZONS_CHOICE]) if RAW_AMAZONS_CHOICE else None
  
			#Converting List to a customized query string to be inserted to the MySQL database.

			leftside_image = Vertical_image1 if Vertical_image1 else None
        

			bottom_image = Bottom_image1 if Bottom_image1 else None,
      

			if page.status_code!=200:
				raise ValueError('captcha')
				sys.exit("captcha Error is coming")
			scarpedata = {
                
						#'current_date' : currentdate,
						'asin_id_api' : asin_id,
						'brand_api' : BRAND,
						'title_api' : NAME,
						'small_image_api' : 'small_image1',
						'sale_price_api' : SALE_PRICE,
						'best_sellers_rank_api' : bsr1,
                
						'date_exported' : Date_Time, #'2018-11-13 19:04:35', # 
						'curr_date' : currentdate , #.strftime('%m/%d/%Y'), #'11/13/2018' , #
                
						'search_keyword' : search_key,
                
						'asin_id' : asin_id,
                
						'title':NAME,
						'sale_price':SALE_PRICE,
							'category':CATEGORY,
							'original_price':ORIGINAL_PRICE if ORIGINAL_PRICE else SALE_PRICE,
							'availability':AVAILABILITY,
							'brand' :BRAND,

							'feature_bullets' : json.dumps(FEATURE_BULLETS),
							'descritpion' : json.dumps(DESCRIPTION),
                
							'customer_reviews' :CUSTOMER_REVIEWS,
							'search_url':main_url,                
							'asin_url':url,
							'Five_Star_Rating' : RAW_Total_Rating[0].replace('%','') if Total_Rating else None,
							'Four_Star_Rating' : RAW_Total_Rating[1].replace('%','') if Total_Rating else None,
							'Three_Star_Rating' : RAW_Total_Rating[2].replace('%','') if Total_Rating else None,
							'Two_Star_Rating' : RAW_Total_Rating[3].replace('%','') if Total_Rating else None,
							'One_Star_Rating' : RAW_Total_Rating[4].replace('%','') if Total_Rating else None,
							'amazon_best_sellers_rank_1':bsr1,
							'amazon_best_sellers_category_1':cat1,                
							'amazon_best_sellers_rank_2':bsr2,
							'amazon_best_sellers_category_2':cat2,
							'amazon_best_sellers_rank_3':bsr3,
							'amazon_best_sellers_category_3':cat3,
							'fullfilled_by_amazon':FULLFILLED_BY_AMAZON1,                
							'amazons_choice':AMAZONS_CHOICE1,
                
							'amazons_leftside_image':json.dumps(leftside_image),
                
							'count_leftside_images':len(Vertical_image1) if Vertical_image1 else 0,
                
							'amazons_bottom_image': json.dumps(bottom_image),
                
						'count_colour_variations':len(Bottom_image1) if Bottom_image1 else 0,

					}
			return scarpedata
		except Exception as e:
			print (e)

# %%
if __name__ == "__main__":
    ReadAsin()
# Out:
# Processing: https://www.amazon.com/dp/B01NCEWK40
# ['94.253.14.187:55045', '103.236.203.139:3128', '190.214.53.66:40218', '91.232.146.7:47924', '54.39.144.247:9090', '159.65.18.117:3128', '190.152.71.122:21231', '181.112.57.34:52476', '176.120.217.148:41258', '149.56.129.139:8888']
# {'https': '54.39.144.247:9090'}
# Connected to the Proxy IP
# None
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Title is coming as None
# C:\Users\Sree\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
smtpObj = smtplib.SMTP('smtp-mail.outlook.com', 587)
smtpObj.ehlo()
smtpObj.starttls()
smtpObj.login('consultant2@royale.com.au', 'welcome')
FROM = "consultant2@royale.com.au"
TO = ["consultant2@royale.com.au"] # must be a list

SUBJECT = "API_KC_2 Run"

TEXT1 = "Hi All, \nThe API data for API_KC_2 is successfully completed \nThanks, Sree"

# Prepare actual message
message = """From: %s\r\nTo: %s\r\nSubject: %s\r\n\

# %s
""" % (FROM, ", ".join(TO), SUBJECT, TEXT1)

smtpObj.sendmail(FROM, TO, message)

smtpObj.quit()

# %%
sys.exit("The script is completed Successfully")
